# %%
### Housekeeping ###
import os, requests, time

### Data ###
import numpy as np
import pandas as pd
import scipy.io

### Visualization ###
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

### Machine Learning ###
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

### Statistics ###
import scipy.stats as stats
import statsmodels.stats.multitest as smm

### RNA-Seq ###
from pydeseq2.dds import DeseqDataSet
from pydeseq2.default_inference import DefaultInference
from pydeseq2.ds import DeseqStats
from pydeseq2.utils import load_example_data

import gseapy as gp
from gseapy.plot import gseaplot
# Out:
# /Users/ninaadkalla/.pyenv/versions/3.10.6/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.16) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(

# %%
dir = os.path.join('..', 'data', 'E-GEOD-60052.csv')
df = pd.read_csv(dir, index_col=0)
df
# Out:
#                             condition  TSPAN6  TNMD  DPM1  SCYL3  C1orf112  \
# SRR1797218                     normal      99    51    33     67        39
# SRR1797219                     normal      33     2    52    141       110
# SRR1797220                     normal      14    26    11     45        28
# SRR1797221                     normal      14    13     0     23        52
# SRR1797222                     normal      48     0    12    183        53
# ...                               ...     ...   ...   ...    ...       ...
# SRR1797299  small cell lung carcinoma      85    58   147    117       127
# SRR1797300  small cell lung carcinoma      42    85    18     18        41
# SRR1797301  small cell lung carcinoma      49     4   121    167       224
# SRR1797302  small cell lung carcinoma     109     0    66     27       100
# SRR1797303  small cell lung carcinoma       2    23    11     57         1
#
#             FGR  CFH  FUCA2  GCLC  ...  ENSG00000281913  ENSG00000281914  \
# SRR1797218  128  597     20   171  ...                0                0
# SRR1797219  419  454     57   198  ...                0                0
# SRR1797220  197  473     17    90  ...                0                0
# SRR1797221   76   65     14    30  ...                0                0
# SRR1797222  314  134     60   299  ...                0                0
# ...         ...  ...    ...   ...  ...              ...              ...
# SRR1797299    0  222    196   221  ...                0                0
# SRR1797300  241  756      9   195  ...                0                0
# SRR1797301   47  466     57   444  ...                0                0
# SRR1797302  139  583     70   139  ...                0                0
# SRR1797303   59  223      0   291  ...                0                0
#
#             ENSG00000281915  ENSG00000281916  ENSG00000281917  \
# SRR1797218                0                0                0
# SRR1797219                0                0                0
# SRR1797220                0                0                0
# SRR1797221                0                0                0
# SRR1797222                0                0                0
# ...                     ...              ...              ...
# SRR1797299                0                0                0
# SRR1797300                0                0                0
# SRR1797301                0                0                0
# SRR1797302                0                0                0
# SRR1797303                0                0                0
#
#             ENSG00000281918  ENSG00000281919  ENSG00000281920  \
# SRR1797218                0                0                0
# SRR1797219                0                0                0
# SRR1797220                6                0                0
# SRR1797221                0                0                1
# SRR1797222                6                0                5
# ...                     ...              ...              ...
# SRR1797299               12                0                3
# SRR1797300                0                0                0
# SRR1797301               32                0                0
# SRR1797302                0                0                0
# SRR1797303                0                0                0
#
#             ENSG00000281921  ENSG00000281922
# SRR1797218                0                0
# SRR1797219                0                0
# SRR1797220                0                0
# SRR1797221                0                0
# SRR1797222                0                0
# ...                     ...              ...
# SRR1797299                0                0
# SRR1797300                0                0
# SRR1797301                0                0
# SRR1797302                0                0
# SRR1797303                0                0
#
# [86 rows x 65218 columns]

# %%
df = df.loc[:,~df.columns.duplicated()].copy()
df
# Out:
#                             condition  TSPAN6  TNMD  DPM1  SCYL3  C1orf112  \
# SRR1797218                     normal      99    51    33     67        39
# SRR1797219                     normal      33     2    52    141       110
# SRR1797220                     normal      14    26    11     45        28
# SRR1797221                     normal      14    13     0     23        52
# SRR1797222                     normal      48     0    12    183        53
# ...                               ...     ...   ...   ...    ...       ...
# SRR1797299  small cell lung carcinoma      85    58   147    117       127
# SRR1797300  small cell lung carcinoma      42    85    18     18        41
# SRR1797301  small cell lung carcinoma      49     4   121    167       224
# SRR1797302  small cell lung carcinoma     109     0    66     27       100
# SRR1797303  small cell lung carcinoma       2    23    11     57         1
#
#             FGR  CFH  FUCA2  GCLC  ...  ENSG00000281913  ENSG00000281914  \
# SRR1797218  128  597     20   171  ...                0                0
# SRR1797219  419  454     57   198  ...                0                0
# SRR1797220  197  473     17    90  ...                0                0
# SRR1797221   76   65     14    30  ...                0                0
# SRR1797222  314  134     60   299  ...                0                0
# ...         ...  ...    ...   ...  ...              ...              ...
# SRR1797299    0  222    196   221  ...                0                0
# SRR1797300  241  756      9   195  ...                0                0
# SRR1797301   47  466     57   444  ...                0                0
# SRR1797302  139  583     70   139  ...                0                0
# SRR1797303   59  223      0   291  ...                0                0
#
#             ENSG00000281915  ENSG00000281916  ENSG00000281917  \
# SRR1797218                0                0                0
# SRR1797219                0                0                0
# SRR1797220                0                0                0
# SRR1797221                0                0                0
# SRR1797222                0                0                0
# ...                     ...              ...              ...
# SRR1797299                0                0                0
# SRR1797300                0                0                0
# SRR1797301                0                0                0
# SRR1797302                0                0                0
# SRR1797303                0                0                0
#
#             ENSG00000281918  ENSG00000281919  ENSG00000281920  \
# SRR1797218                0                0                0
# SRR1797219                0                0                0
# SRR1797220                6                0                0
# SRR1797221                0                0                1
# SRR1797222                6                0                5
# ...                     ...              ...              ...
# SRR1797299               12                0                3
# SRR1797300                0                0                0
# SRR1797301               32                0                0
# SRR1797302                0                0                0
# SRR1797303                0                0                0
#
#             ENSG00000281921  ENSG00000281922
# SRR1797218                0                0
# SRR1797219                0                0
# SRR1797220                0                0
# SRR1797221                0                0
# SRR1797222                0                0
# ...                     ...              ...
# SRR1797299                0                0
# SRR1797300                0                0
# SRR1797301                0                0
# SRR1797302                0                0
# SRR1797303                0                0
#
# [86 rows x 65218 columns]

# %%
meta_df = df['condition'].reset_index().rename(columns={'index':'sample'})
meta_df = meta_df.set_index('sample').rename_axis(None)
meta_df
# Out:
#                             condition
# SRR1797218                     normal
# SRR1797219                     normal
# SRR1797220                     normal
# SRR1797221                     normal
# SRR1797222                     normal
# ...                               ...
# SRR1797299  small cell lung carcinoma
# SRR1797300  small cell lung carcinoma
# SRR1797301  small cell lung carcinoma
# SRR1797302  small cell lung carcinoma
# SRR1797303  small cell lung carcinoma
#
# [86 rows x 1 columns]

# %%
df = df.drop(columns=['condition'])
df
# Out:
#             TSPAN6  TNMD  DPM1  SCYL3  C1orf112  FGR  CFH  FUCA2  GCLC  NFYA  \
# SRR1797218      99    51    33     67        39  128  597     20   171   153
# SRR1797219      33     2    52    141       110  419  454     57   198   155
# SRR1797220      14    26    11     45        28  197  473     17    90   147
# SRR1797221      14    13     0     23        52   76   65     14    30    11
# SRR1797222      48     0    12    183        53  314  134     60   299   133
# ...            ...   ...   ...    ...       ...  ...  ...    ...   ...   ...
# SRR1797299      85    58   147    117       127    0  222    196   221   642
# SRR1797300      42    85    18     18        41  241  756      9   195   184
# SRR1797301      49     4   121    167       224   47  466     57   444   266
# SRR1797302     109     0    66     27       100  139  583     70   139   212
# SRR1797303       2    23    11     57         1   59  223      0   291   166
#
#             ...  ENSG00000281913  ENSG00000281914  ENSG00000281915  \
# SRR1797218  ...                0                0                0
# SRR1797219  ...                0                0                0
# SRR1797220  ...                0                0                0
# SRR1797221  ...                0                0                0
# SRR1797222  ...                0                0                0
# ...         ...              ...              ...              ...
# SRR1797299  ...                0                0                0
# SRR1797300  ...                0                0                0
# SRR1797301  ...                0                0                0
# SRR1797302  ...                0                0                0
# SRR1797303  ...                0                0                0
#
#             ENSG00000281916  ENSG00000281917  ENSG00000281918  \
# SRR1797218                0                0                0
# SRR1797219                0                0                0
# SRR1797220                0                0                6
# SRR1797221                0                0                0
# SRR1797222                0                0                6
# ...                     ...              ...              ...
# SRR1797299                0                0               12
# SRR1797300                0                0                0
# SRR1797301                0                0               32
# SRR1797302                0                0                0
# SRR1797303                0                0                0
#
#             ENSG00000281919  ENSG00000281920  ENSG00000281921  ENSG00000281922
# SRR1797218                0                0                0                0
# SRR1797219                0                0                0                0
# SRR1797220                0                0                0                0
# SRR1797221                0                1                0                0
# SRR1797222                0                5                0                0
# ...                     ...              ...              ...              ...
# SRR1797299                0                3                0                0
# SRR1797300                0                0                0                0
# SRR1797301                0                0                0                0
# SRR1797302                0                0                0                0
# SRR1797303                0                0                0                0
#
# [86 rows x 65217 columns]

# %%
df.shape
# Out:
# (86, 65217)

# %%
genes_to_keep = df.columns[df.sum(axis=0) >= 10]
len(genes_to_keep)
# Out:
# 56016

# %%
filtered_df = df[genes_to_keep]
filtered_df
# Out:
#             TSPAN6  TNMD  DPM1  SCYL3  C1orf112  FGR  CFH  FUCA2  GCLC  NFYA  \
# SRR1797218      99    51    33     67        39  128  597     20   171   153
# SRR1797219      33     2    52    141       110  419  454     57   198   155
# SRR1797220      14    26    11     45        28  197  473     17    90   147
# SRR1797221      14    13     0     23        52   76   65     14    30    11
# SRR1797222      48     0    12    183        53  314  134     60   299   133
# ...            ...   ...   ...    ...       ...  ...  ...    ...   ...   ...
# SRR1797299      85    58   147    117       127    0  222    196   221   642
# SRR1797300      42    85    18     18        41  241  756      9   195   184
# SRR1797301      49     4   121    167       224   47  466     57   444   266
# SRR1797302     109     0    66     27       100  139  583     70   139   212
# SRR1797303       2    23    11     57         1   59  223      0   291   166
#
#             ...  ENSG00000281896  LINC02246  ENSG00000281904  ENSG00000281905  \
# SRR1797218  ...                6          9                6                0
# SRR1797219  ...               79         15               31                0
# SRR1797220  ...               15          0                9                0
# SRR1797221  ...               13          0              135                0
# SRR1797222  ...               65          0               38                0
# ...         ...              ...        ...              ...              ...
# SRR1797299  ...               19          0               37                0
# SRR1797300  ...               15          3                3                0
# SRR1797301  ...               46          0               75                0
# SRR1797302  ...               24          0               75                0
# SRR1797303  ...               99          0              176                0
#
#             HERC2P7.1  SNORA50A.1  LINC01144  ENSG00000281918  \
# SRR1797218          0           0          1                0
# SRR1797219          2          25          0                0
# SRR1797220          0           0          0                6
# SRR1797221          0           0          0                0
# SRR1797222          0           7          0                6
# ...               ...         ...        ...              ...
# SRR1797299          0           6         26               12
# SRR1797300          0           2          0                0
# SRR1797301          2           0         13               32
# SRR1797302          0           0          0                0
# SRR1797303          0           1          0                0
#
#             ENSG00000281920  ENSG00000281921
# SRR1797218                0                0
# SRR1797219                0                0
# SRR1797220                0                0
# SRR1797221                1                0
# SRR1797222                5                0
# ...                     ...              ...
# SRR1797299                3                0
# SRR1797300                0                0
# SRR1797301                0                0
# SRR1797302                0                0
# SRR1797303                0                0
#
# [86 rows x 56016 columns]

# %%
inference = DefaultInference(n_cpus=8)
dds = DeseqDataSet(
    counts=df,
    metadata=meta_df,
    design_factors="condition",
    refit_cooks=True,
    inference=inference,
)

# %%
dds
# Out:
# AnnData object with n_obs × n_vars = 86 × 65217
#     obs: 'condition'
#     obsm: 'design_matrix'

# %%
dds.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.07 seconds.
#
# Fitting dispersions...
# ... done in 4.73 seconds.
#
# Fitting dispersion trend curve...
# ... done in 1.06 seconds.
#
# Fitting MAP dispersions...
# ... done in 4.58 seconds.
#
# Fitting LFCs...
# ... done in 3.56 seconds.
#
# Refitting 3111 outliers.
#
# Fitting dispersions...
# ... done in 0.25 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.25 seconds.
#
# Fitting LFCs...
# ... done in 0.22 seconds.
#
# /Users/ninaadkalla/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pydeseq2/dds.py:1019: ImplicitModificationWarning: Setting element `.varm['_normed_means']` of view, initializing view as actual.
#   self[:, self.new_all_zeroes_genes].varm["_normed_means"] = np.zeros(
# /Users/ninaadkalla/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pydeseq2/dds.py:1022: ImplicitModificationWarning: Setting element `.varm['LFC']` of view, initializing view as actual.
#   self[:, self.new_all_zeroes_genes].varm["LFC"] = np.zeros(

# %%
dds
# Out:
# AnnData object with n_obs × n_vars = 86 × 65217
#     obs: 'condition'
#     uns: 'trend_coeffs', '_squared_logres', 'prior_disp_var'
#     obsm: 'design_matrix', 'size_factors', 'replaceable'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks'

# %%
stat_res = DeseqStats(dds, inference=inference)
stat_res.summary()
# Out:
# Running Wald tests...
# ... done in 1.76 seconds.
# Log2 fold change & Wald test p-value: condition small cell lung carcinoma vs normal
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# TSPAN6            50.068813        0.186334  0.412251  0.451991  0.651276
# TNMD               6.722537       -1.378788  1.111712 -1.240239  0.214887
# DPM1              38.271571        0.624634  0.422328  1.479025  0.139134
# SCYL3            106.323251        0.600443  0.258667  2.321295  0.020271
# C1orf112         122.884403        1.117855  0.351354  3.181562  0.001465
# ...                     ...             ...       ...       ...       ...
# ENSG00000281918    7.537101        2.352306  0.964029  2.440079  0.014684
# ENSG00000281919    0.000000             NaN       NaN       NaN       NaN
# ENSG00000281920    9.557405        3.829074  1.430825  2.676129  0.007448
# ENSG00000281921    0.719867        2.229193  3.400970  0.655458  0.512173
# ENSG00000281922    0.000000             NaN       NaN       NaN       NaN
#
#                      padj
# TSPAN6           0.815979
# TNMD             0.422666
# DPM1             0.319629
# SCYL3            0.087005
# C1orf112         0.013681
# ...                   ...
# ENSG00000281918  0.069911
# ENSG00000281919       NaN
# ENSG00000281920  0.043905
# ENSG00000281921       NaN
# ENSG00000281922       NaN
#
# [65217 rows x 6 columns]

# %%
results = stat_res.results_df
results
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# TSPAN6            50.068813        0.186334  0.412251  0.451991  0.651276
# TNMD               6.722537       -1.378788  1.111712 -1.240239  0.214887
# DPM1              38.271571        0.624634  0.422328  1.479025  0.139134
# SCYL3            106.323251        0.600443  0.258667  2.321295  0.020271
# C1orf112         122.884403        1.117855  0.351354  3.181562  0.001465
# ...                     ...             ...       ...       ...       ...
# ENSG00000281918    7.537101        2.352306  0.964029  2.440079  0.014684
# ENSG00000281919    0.000000             NaN       NaN       NaN       NaN
# ENSG00000281920    9.557405        3.829074  1.430825  2.676129  0.007448
# ENSG00000281921    0.719867        2.229193  3.400970  0.655458  0.512173
# ENSG00000281922    0.000000             NaN       NaN       NaN       NaN
#
#                      padj
# TSPAN6           0.815979
# TNMD             0.422666
# DPM1             0.319629
# SCYL3            0.087005
# C1orf112         0.013681
# ...                   ...
# ENSG00000281918  0.069911
# ENSG00000281919       NaN
# ENSG00000281920  0.043905
# ENSG00000281921       NaN
# ENSG00000281922       NaN
#
# [65217 rows x 6 columns]

# %%
results = results[(results['padj'] < 0.05)]
results = results[(abs(results['log2FoldChange']) > 0.05)]
results = results[(results['baseMean'] > 20)]
results
# Out:
#                     baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# C1orf112          122.884403        1.117855  0.351354  3.181562  0.001465
# FGR                55.528507       -2.368954  0.576093 -4.112105  0.000039
# STPG1              86.443931        1.000003  0.338278  2.956154  0.003115
# MYH16              49.771122        1.938114  0.675608  2.868698  0.004122
# CD99              205.021743       -1.877996  0.489489 -3.836647  0.000125
# ...                      ...             ...       ...       ...       ...
# ENSG00000280783    26.814512        1.791200  0.519264  3.449501  0.000562
# LINC00294         175.706382        0.808593  0.276039  2.929269  0.003398
# LINC00997         177.999021        0.975662  0.292882  3.331246  0.000865
# LINC00506        2091.780524        1.252806  0.476021  2.631827  0.008493
# DBET              106.364208        2.773954  1.058021  2.621832  0.008746
#
#                      padj
# C1orf112         0.013681
# FGR              0.000900
# STPG1            0.023684
# MYH16            0.028888
# CD99             0.002217
# ...                   ...
# ENSG00000280783  0.006823
# LINC00294        0.025166
# LINC00997        0.009264
# LINC00506        0.047939
# DBET             0.048919
#
# [4381 rows x 6 columns]

# %%
results.sort_values(by=['log2FoldChange'], ascending=False, inplace=True)
results
# Out:
#                baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# HNRNPA1P42    27.615679        7.679569  1.482099  5.181550  2.200499e-07
# PABPC1P11     32.590847        7.503462  1.215853  6.171359  6.770569e-10
# POLR3GP2      21.844447        7.330169  1.703677  4.302558  1.688376e-05
# FAM83A        20.423203        7.233236  1.482740  4.878289  1.070103e-06
# THEG          22.237465        6.950658  1.370182  5.072798  3.920092e-07
# ...                 ...             ...       ...       ...           ...
# SFTPA1      1822.220830       -4.748982  0.898820 -5.283576  1.266862e-07
# SFTPA2      2831.561330       -4.798173  0.906014 -5.295915  1.184220e-07
# PGC          108.757986       -4.935291  0.707069 -6.979933  2.953201e-12
# ADAMTS7P3     51.561853       -4.970657  0.993212 -5.004630  5.596948e-07
# SFTPC        983.848853       -5.305889  1.005274 -5.278050  1.305655e-07
#
#                     padj
# HNRNPA1P42  1.581557e-05
# PABPC1P11   1.806902e-07
# POLR3GP2    4.764404e-04
# FAM83A      5.649392e-05
# THEG        2.515929e-05
# ...                  ...
# SFTPA1      1.050671e-05
# SFTPA2      9.968003e-06
# PGC         2.904853e-09
# ADAMTS7P3   3.362759e-05
# SFTPC       1.064179e-05
#
# [4381 rows x 6 columns]

# %%
df
# Out:
#             TSPAN6  TNMD  DPM1  SCYL3  C1orf112  FGR  CFH  FUCA2  GCLC  NFYA  \
# SRR1797218      99    51    33     67        39  128  597     20   171   153
# SRR1797219      33     2    52    141       110  419  454     57   198   155
# SRR1797220      14    26    11     45        28  197  473     17    90   147
# SRR1797221      14    13     0     23        52   76   65     14    30    11
# SRR1797222      48     0    12    183        53  314  134     60   299   133
# ...            ...   ...   ...    ...       ...  ...  ...    ...   ...   ...
# SRR1797299      85    58   147    117       127    0  222    196   221   642
# SRR1797300      42    85    18     18        41  241  756      9   195   184
# SRR1797301      49     4   121    167       224   47  466     57   444   266
# SRR1797302     109     0    66     27       100  139  583     70   139   212
# SRR1797303       2    23    11     57         1   59  223      0   291   166
#
#             ...  ENSG00000281913  ENSG00000281914  ENSG00000281915  \
# SRR1797218  ...                0                0                0
# SRR1797219  ...                0                0                0
# SRR1797220  ...                0                0                0
# SRR1797221  ...                0                0                0
# SRR1797222  ...                0                0                0
# ...         ...              ...              ...              ...
# SRR1797299  ...                0                0                0
# SRR1797300  ...                0                0                0
# SRR1797301  ...                0                0                0
# SRR1797302  ...                0                0                0
# SRR1797303  ...                0                0                0
#
#             ENSG00000281916  ENSG00000281917  ENSG00000281918  \
# SRR1797218                0                0                0
# SRR1797219                0                0                0
# SRR1797220                0                0                6
# SRR1797221                0                0                0
# SRR1797222                0                0                6
# ...                     ...              ...              ...
# SRR1797299                0                0               12
# SRR1797300                0                0                0
# SRR1797301                0                0               32
# SRR1797302                0                0                0
# SRR1797303                0                0                0
#
#             ENSG00000281919  ENSG00000281920  ENSG00000281921  ENSG00000281922
# SRR1797218                0                0                0                0
# SRR1797219                0                0                0                0
# SRR1797220                0                0                0                0
# SRR1797221                0                1                0                0
# SRR1797222                0                5                0                0
# ...                     ...              ...              ...              ...
# SRR1797299                0                3                0                0
# SRR1797300                0                0                0                0
# SRR1797301                0                0                0                0
# SRR1797302                0                0                0                0
# SRR1797303                0                0                0                0
#
# [86 rows x 65217 columns]

# %%
results
# Out:
#                baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# HNRNPA1P42    27.615679        7.679569  1.482099  5.181550  2.200499e-07
# PABPC1P11     32.590847        7.503462  1.215853  6.171359  6.770569e-10
# POLR3GP2      21.844447        7.330169  1.703677  4.302558  1.688376e-05
# FAM83A        20.423203        7.233236  1.482740  4.878289  1.070103e-06
# THEG          22.237465        6.950658  1.370182  5.072798  3.920092e-07
# ...                 ...             ...       ...       ...           ...
# SFTPA1      1822.220830       -4.748982  0.898820 -5.283576  1.266862e-07
# SFTPA2      2831.561330       -4.798173  0.906014 -5.295915  1.184220e-07
# PGC          108.757986       -4.935291  0.707069 -6.979933  2.953201e-12
# ADAMTS7P3     51.561853       -4.970657  0.993212 -5.004630  5.596948e-07
# SFTPC        983.848853       -5.305889  1.005274 -5.278050  1.305655e-07
#
#                     padj
# HNRNPA1P42  1.581557e-05
# PABPC1P11   1.806902e-07
# POLR3GP2    4.764404e-04
# FAM83A      5.649392e-05
# THEG        2.515929e-05
# ...                  ...
# SFTPA1      1.050671e-05
# SFTPA2      9.968003e-06
# PGC         2.904853e-09
# ADAMTS7P3   3.362759e-05
# SFTPC       1.064179e-05
#
# [4381 rows x 6 columns]

# %%
data = pd.concat([results.head(50), results.tail(50)])
data
# Out:
#                baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# HNRNPA1P42    27.615679        7.679569  1.482099  5.181550  2.200499e-07
# PABPC1P11     32.590847        7.503462  1.215853  6.171359  6.770569e-10
# POLR3GP2      21.844447        7.330169  1.703677  4.302558  1.688376e-05
# FAM83A        20.423203        7.233236  1.482740  4.878289  1.070103e-06
# THEG          22.237465        6.950658  1.370182  5.072798  3.920092e-07
# ...                 ...             ...       ...       ...           ...
# SFTPA1      1822.220830       -4.748982  0.898820 -5.283576  1.266862e-07
# SFTPA2      2831.561330       -4.798173  0.906014 -5.295915  1.184220e-07
# PGC          108.757986       -4.935291  0.707069 -6.979933  2.953201e-12
# ADAMTS7P3     51.561853       -4.970657  0.993212 -5.004630  5.596948e-07
# SFTPC        983.848853       -5.305889  1.005274 -5.278050  1.305655e-07
#
#                     padj
# HNRNPA1P42  1.581557e-05
# PABPC1P11   1.806902e-07
# POLR3GP2    4.764404e-04
# FAM83A      5.649392e-05
# THEG        2.515929e-05
# ...                  ...
# SFTPA1      1.050671e-05
# SFTPA2      9.968003e-06
# PGC         2.904853e-09
# ADAMTS7P3   3.362759e-05
# SFTPC       1.064179e-05
#
# [100 rows x 6 columns]

# %%
data.index
# Out:
# Index(['HNRNPA1P42', 'PABPC1P11', 'POLR3GP2', 'FAM83A', 'THEG', 'HOXD10',
#        'NEUROG3', 'CYP4F23P', 'VGF', 'KRTAP10-10', 'ENSG00000246528', 'GRK1',
#        'NKX2-2', 'NGB', 'PATE1', 'SCRT1', 'ENSG00000254314', 'ENSG00000272763',
#        'LINC00552', 'C1QL1', 'HNRNPA3P16', 'TCEAL6', 'TTC9B', 'CNGA3', 'PITX2',
#        'NEUROD4', 'SCGB2A2', 'TP73-AS3', 'MIR217HG', 'DLX2', 'LINGO2',
#        'TMEM151B', 'ENSG00000272372', 'SLC45A2', 'SLC6A17', 'RALYL', 'CRIP3',
#        'KCNH7', 'TRIM9', 'OPRK1', 'ENSG00000231754', 'CDH22', 'ATP4B', 'FOXN4',
#        'CRABP1', 'DMRTA2', 'C14orf180', 'ARNILA', 'GNRH2', 'CNGB1', 'CLIC5',
#        'FENDRR', 'LGI3', 'PRX', 'TMPRSS2', 'SLC6A4', 'CXCL8', 'SFTPB', 'TCF21',
#        'AOC3', 'SDR16C5', 'SLC39A8', 'TMEM100', 'GPIHBP1', 'LHFPL3-AS2',
#        'VIPR1', 'SUSD2', 'FOSB', 'SCEL', 'CXCL2', 'ANKRD1', 'SFTPD', 'RGCC',
#        'EDN1', 'HBA1', 'IL1RL1', 'CSRNP1', 'SCGB1A1', 'CAVIN2', 'CSF3', 'MSLN',
#        'ICAM1', 'FAM107A', 'CLDN18', 'SLC34A2', 'BTNL9', 'AGER', 'EPAS1',
#        'CYP4B1', 'CAV1', 'UPK3B', 'HBB', 'PLA2G4F', 'HBA2', 'FCN3', 'SFTPA1',
#        'SFTPA2', 'PGC', 'ADAMTS7P3', 'SFTPC'],
#       dtype='object')

# %%
genes = list(data.index)
genes[:5]
# Out:
# ['HNRNPA1P42', 'PABPC1P11', 'POLR3GP2', 'FAM83A', 'THEG']

# %%
def get_gene_name(ensembl_id):
    if ensembl_id[:4] == 'ENSG':
        try:
            url = f"https://mygene.info/v3/gene/{ensembl_id}"
            response = requests.get(url)
            data = response.json()

            # Check if 'symbol' is in the data and not None
            if 'symbol' in data and data['symbol'] is not None:
                return data['symbol']
            else:
                return None
        except Exception as e:
            print(f"An error occurred: {e}")
            return None
    else:
        return ensembl_id

# %%
genes = [get_gene_name(g) for g in genes]
genes[-5:]
# Out:
# ['SFTPA1', 'SFTPA2', 'PGC', 'ADAMTS7P3', 'SFTPC']

# %%
def fetch_interactions(gene_name):
    url = "https://string-db.org/api/json/network"
    retries = 0
    max_retries = 3

    while retries < max_retries:
        try:
            response = requests.get(url, params={"identifiers": gene_name})
            response.raise_for_status()  # Raises a HTTPError for bad responses
            # If response is successful, parse and return the JSON data
            interactions_data = response.json()
            return interactions_data
        except requests.RequestException as e:
            print(f"Attempt {retries + 1} failed: {e}")
            if retries == max_retries - 1:
                print(f"Failed to fetch interactions for {gene_name} after {max_retries} attempts.")
                return []  # Return an empty list after all retries have been exhausted
        finally:
            retries += 1

# %%
all_pairs = []
for gene in genes:
    interactions_json = fetch_interactions(gene)
    for interaction in interactions_json:
        nameA = interaction['preferredName_A']
        nameB = interaction['preferredName_B']
        all_pairs.append([nameA, nameB])
all_pairs
# Out:
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=HNRNPA1P42
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=HNRNPA1P42
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=HNRNPA1P42
# Failed to fetch interactions for HNRNPA1P42 after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=PABPC1P11
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=PABPC1P11
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=PABPC1P11
# Failed to fetch interactions for PABPC1P11 after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=POLR3GP2
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=POLR3GP2
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=POLR3GP2
# Failed to fetch interactions for POLR3GP2 after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=CYP4F23P
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=CYP4F23P
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=CYP4F23P
# Failed to fetch interactions for CYP4F23P after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=SLCO5A1-AS1
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=SLCO5A1-AS1
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=SLCO5A1-AS1
# Failed to fetch interactions for SLCO5A1-AS1 after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network
# Failed to fetch interactions for None after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=LINC03057
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=LINC03057
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=LINC03057
# Failed to fetch interactions for LINC03057 after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=LINC00552
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=LINC00552
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=LINC00552
# Failed to fetch interactions for LINC00552 after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=HNRNPA3P16
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=HNRNPA3P16
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=HNRNPA3P16
# Failed to fetch interactions for HNRNPA3P16 after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=TP73-AS3
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=TP73-AS3
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=TP73-AS3
# Failed to fetch interactions for TP73-AS3 after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=MIR217HG
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=MIR217HG
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=MIR217HG
# Failed to fetch interactions for MIR217HG after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network
# Failed to fetch interactions for None after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network
# Failed to fetch interactions for None after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=ARNILA
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=ARNILA
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=ARNILA
# Failed to fetch interactions for ARNILA after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=FENDRR
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=FENDRR
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=FENDRR
# Failed to fetch interactions for FENDRR after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=LHFPL3-AS2
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=LHFPL3-AS2
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=LHFPL3-AS2
# Failed to fetch interactions for LHFPL3-AS2 after 3 attempts.
# Attempt 1 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=ADAMTS7P3
# Attempt 2 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=ADAMTS7P3
# Attempt 3 failed: 400 Client Error: Bad Request for url: https://string-db.org/api/json/network?identifiers=ADAMTS7P3
# Failed to fetch interactions for ADAMTS7P3 after 3 attempts.
# [['DHX35', 'DERL1'],
#  ['DHX35', 'FAM83A'],
#  ['DHX35', 'ZHX3'],
#  ['DHX35', 'RAB5IF'],
#  ['DHX35', 'TBC1D31'],
#  ['DERL1', 'FAM83A'],
#  ['DERL1', 'RAB5IF'],
#  ['DERL1', 'TBC1D31'],
#  ['CSNK1A1', 'FAM83A'],
#  ['CSNK1A1', 'CSNK1E'],
#  ['TBC1D31', 'RAB5IF'],
#  ['TBC1D31', 'FAM83A'],
#  ['TBC1D31', 'ZHX3'],
#  ['TP53I13', 'FAM83A'],
#  ['TP53I13', 'LOC107987373'],
#  ['TP53I13', 'MRPL23'],
#  ['ZHX3', 'FAM83A'],
#  ['ZHX3', 'RAB5IF'],
#  ['RAB5IF', 'FAM83A'],
#  ['CSNK1E', 'FAM83A'],
#  ['MRPL23', 'FAM83A'],
#  ['FAM83A', 'LOC107987373'],
#  ['PRSS54', 'CT62'],
#  ['PRSS54', 'THEG'],
#  ['ACRBP', 'THEG'],
#  ['ACRBP', 'SPACA3'],
#  ['MIER2', 'R3HDM4'],
#  ['MIER2', 'THEG'],
#  ['SPACA3', 'CT62'],
#  ['SPACA3', 'THEG'],
#  ['CCT5', 'THEG'],
#  ['SPATA12', 'THEG'],
#  ['THEG', 'R3HDM4'],
#  ['THEG', 'PECAM1'],
#  ['THEG', 'DNAJC28'],
#  ['THEG', 'CT62'],
#  ['HOXB7', 'HOXD9'],
#  ['HOXB7', 'MEIS1'],
#  ['HOXB7', 'HOXD10'],
#  ['HOXD9', 'HOXD1'],
#  ['HOXD9', 'EVX2'],
#  ['HOXD9', 'MEIS1'],
#  ['HOXD9', 'SHH'],
#  ['HOXD9', 'HOXD13'],
#  ['HOXD9', 'HOXD11'],
#  ['HOXD9', 'HOXD3'],
#  ['HOXD9', 'HOXD10'],
#  ['HOXD10', 'HOXD1'],
#  ['HOXD10', 'EVX2'],
#  ['HOXD10', 'MEIS1'],
#  ['HOXD10', 'SHH'],
#  ['HOXD10', 'HOXD3'],
#  ['HOXD10', 'HOXD13'],
#  ['HOXD10', 'RHOC'],
#  ['HOXD10', 'HOXD11'],
#  ['HOXD11', 'HOXD3'],
#  ['HOXD11', 'HOXD1'],
#  ['HOXD11', 'EVX2'],
#  ['HOXD11', 'SHH'],
#  ['HOXD11', 'HOXD13'],
#  ['MEIS1', 'HOXD13'],
#  ['SHH', 'EVX2'],
#  ['SHH', 'HOXD3'],
#  ['SHH', 'HOXD13'],
#  ['EVX2', 'HOXD1'],
#  ['EVX2', 'HOXD3'],
#  ['EVX2', 'HOXD13'],
#  ['HOXD1', 'HOXD3'],
#  ['HOXD1', 'HOXD13'],
#  ['HOXD13', 'HOXD3'],
#  ['ISL1', 'RFX6'],
#  ['ISL1', 'ONECUT1'],
#  ['ISL1', 'INSM1'],
#  ['ISL1', 'GCG'],
#  ['ISL1', 'NEUROD1'],
#  ['ISL1', 'PAX4'],
#  ['ISL1', 'NKX6-1'],
#  ['ISL1', 'NKX2-2'],
#  ['ISL1', 'NEUROG3'],
#  ['HES1', 'NEUROD1'],
#  ['HES1', 'NEUROG3'],
#  ['NEUROG3', 'NEUROD1'],
#  ['NEUROG3', 'GCG'],
#  ['NEUROG3', 'NKX6-1'],
#  ['NEUROG3', 'RFX6'],
#  ['NEUROG3', 'NKX2-2'],
#  ['NEUROG3', 'INSM1'],
#  ['NEUROG3', 'ONECUT1'],
#  ['NEUROG3', 'PAX4'],
#  ['NEUROD1', 'ONECUT1'],
#  ['NEUROD1', 'RFX6'],
#  ['NEUROD1', 'GCG'],
#  ['NEUROD1', 'NKX6-1'],
#  ['NEUROD1', 'NKX2-2'],
#  ['NEUROD1', 'PAX4'],
#  ['NEUROD1', 'INSM1'],
#  ['NKX6-1', 'PAX4'],
#  ['NKX6-1', 'NKX2-2'],
#  ['NKX6-1', 'INSM1'],
#  ['NKX6-1', 'RFX6'],
#  ['NKX6-1', 'GCG'],
#  ['NKX6-1', 'ONECUT1'],
#  ['ONECUT1', 'GCG'],
#  ['ONECUT1', 'INSM1'],
#  ['ONECUT1', 'PAX4'],
#  ['ONECUT1', 'NKX2-2'],
#  ['ONECUT1', 'RFX6'],
#  ['INSM1', 'GCG'],
#  ['INSM1', 'RFX6'],
#  ['INSM1', 'NKX2-2'],
#  ['INSM1', 'PAX4'],
#  ['RFX6', 'GCG'],
#  ['RFX6', 'NKX2-2'],
#  ['RFX6', 'PAX4'],
#  ['NKX2-2', 'GCG'],
#  ['NKX2-2', 'PAX4'],
#  ['PAX4', 'GCG'],
#  ['OXT', 'CREB1'],
#  ['OXT', 'SCG2'],
#  ['OXT', 'BDNF'],
#  ['OXT', 'VGF'],
#  ['OXT', 'NPY'],
#  ['SCG3', 'NPY'],
#  ['SCG3', 'VGF'],
#  ['SCG3', 'SCG2'],
#  ['SCG3', 'CHGB'],
#  ['EGR1', 'REST'],
#  ['EGR1', 'BDNF'],
#  ['EGR1', 'NGF'],
#  ['EGR1', 'VGF'],
#  ['EGR1', 'CREB1'],
#  ['VGF', 'CREB1'],
#  ['VGF', 'NPY'],
#  ['VGF', 'CHGB'],
#  ['VGF', 'NGF'],
#  ['VGF', 'SCG2'],
#  ['VGF', 'REST'],
#  ['VGF', 'BDNF'],
#  ['SCG2', 'NPY'],
#  ['SCG2', 'CHGB'],
#  ['REST', 'BDNF'],
#  ['REST', 'CREB1'],
#  ['NGF', 'NPY'],
#  ['NGF', 'CREB1'],
#  ['NGF', 'BDNF'],
#  ['CHGB', 'NPY'],
#  ['NPY', 'CREB1'],
#  ['NPY', 'BDNF'],
#  ['CREB1', 'BDNF'],
#  ['KRTAP6-1', 'KRTAP10-10'],
#  ['KRTAP10-11', 'KRTAP10-2'],
#  ['KRTAP10-11', 'KRTAP10-3'],
#  ['KRTAP10-11', 'KRTAP10-5'],
#  ['KRTAP10-11', 'KRTAP10-1'],
#  ['KRTAP10-11', 'KRTAP10-4'],
#  ['KRTAP10-11', 'KRTAP10-10'],
#  ['KRTAP10-11', 'KRTAP10-9'],
#  ['KRTAP10-11', 'KRTAP10-12'],
#  ['KRTAP10-11', 'KRTAP10-7'],
#  ['KRTAP10-10', 'KRTAP10-5'],
#  ['KRTAP10-10', 'KRTAP10-2'],
#  ['KRTAP10-10', 'KRTAP10-4'],
#  ['KRTAP10-10', 'KRTAP10-12'],
#  ['KRTAP10-10', 'KRTAP10-3'],
#  ['KRTAP10-10', 'KRTAP10-1'],
#  ['KRTAP10-10', 'KRTAP10-9'],
#  ['KRTAP10-10', 'KRTAP10-7'],
#  ['KRTAP10-3', 'KRTAP10-12'],
#  ['KRTAP10-3', 'KRTAP10-7'],
#  ['KRTAP10-3', 'KRTAP10-2'],
#  ['KRTAP10-3', 'KRTAP10-4'],
#  ['KRTAP10-3', 'KRTAP10-5'],
#  ['KRTAP10-3', 'KRTAP10-9'],
#  ['KRTAP10-3', 'KRTAP10-1'],
#  ['KRTAP10-2', 'KRTAP10-1'],
#  ['KRTAP10-2', 'KRTAP10-5'],
#  ['KRTAP10-2', 'KRTAP10-9'],
#  ['KRTAP10-2', 'KRTAP10-12'],
#  ['KRTAP10-2', 'KRTAP10-4'],
#  ['KRTAP10-2', 'KRTAP10-7'],
#  ['KRTAP10-9', 'KRTAP10-1'],
#  ['KRTAP10-9', 'KRTAP10-12'],
#  ['KRTAP10-9', 'KRTAP10-4'],
#  ['KRTAP10-9', 'KRTAP10-5'],
#  ['KRTAP10-9', 'KRTAP10-7'],
#  ['KRTAP10-12', 'KRTAP10-5'],
#  ['KRTAP10-12', 'KRTAP10-4'],
#  ['KRTAP10-12', 'KRTAP10-1'],
#  ['KRTAP10-12', 'KRTAP10-7'],
#  ['KRTAP10-5', 'KRTAP10-4'],
#  ['KRTAP10-5', 'KRTAP10-7'],
#  ['KRTAP10-5', 'KRTAP10-1'],
#  ['KRTAP10-4', 'KRTAP10-1'],
#  ['KRTAP10-4', 'KRTAP10-7'],
#  ['KRTAP10-1', 'KRTAP10-7'],
#  ['RCVRN', 'CALML5'],
#  ['RCVRN', 'CALML6'],
#  ['RCVRN', 'ARRB2'],
#  ['RCVRN', 'MPP4'],
#  ['RCVRN', 'SAG'],
#  ['RCVRN', 'RHO'],
#  ['RCVRN', 'GRK7'],
#  ['RCVRN', 'GRK1'],
#  ['GRK7', 'NCS1'],
#  ['GRK7', 'CALML5'],
#  ['GRK7', 'CALML6'],
#  ['GRK7', 'MPP4'],
#  ['GRK7', 'GRK1'],
#  ['GRK7', 'ARRB2'],
#  ['GRK7', 'ARRB1'],
#  ['GRK7', 'SAG'],
#  ['GRK7', 'RHO'],
#  ['RHO', 'NCS1'],
#  ['RHO', 'MPP4'],
#  ['RHO', 'CALML5'],
#  ['RHO', 'CALML6'],
#  ['RHO', 'ARRB2'],
#  ['RHO', 'ARRB1'],
#  ['RHO', 'SAG'],
#  ['RHO', 'GRK1'],
#  ['CALML6', 'ARRB2'],
#  ['CALML6', 'ARRB1'],
#  ['CALML6', 'NCS1'],
#  ['CALML6', 'GRK1'],
#  ['CALML6', 'SAG'],
#  ['CALML6', 'CALML5'],
#  ['GRK1', 'CALML5'],
#  ['GRK1', 'MPP4'],
#  ['GRK1', 'ARRB2'],
#  ['GRK1', 'ARRB1'],
#  ['GRK1', 'NCS1'],
#  ['GRK1', 'SAG'],
#  ['NCS1', 'CALML5'],
#  ['CALML5', 'ARRB2'],
#  ['CALML5', 'ARRB1'],
#  ['CALML5', 'SAG'],
#  ['SAG', 'ARRB2'],
#  ['SAG', 'ARRB1'],
#  ['ARRB2', 'ARRB1'],
#  ['ISL1', 'ASCL1'],
#  ['ISL1', 'INS'],
#  ['ISL1', 'OLIG2'],
#  ['ISL1', 'PAX4'],
#  ['ISL1', 'NKX2-2'],
#  ['ISL1', 'PAX6'],
#  ['ISL1', 'NEUROG3'],
#  ['NEUROG3', 'LMX1B'],
#  ['NEUROG3', 'ASCL1'],
#  ['NEUROG3', 'PAX6'],
#  ['NEUROG3', 'INS'],
#  ['NEUROG3', 'NKX2-2'],
#  ['NEUROG3', 'PAX4'],
#  ['ASCL1', 'PAX6'],
#  ['ASCL1', 'OLIG2'],
#  ['ASCL1', 'LMX1B'],
#  ['ASCL1', 'NKX2-2'],
#  ['OLIG2', 'PAX6'],
#  ['OLIG2', 'NKX2-2'],
#  ['LMX1B', 'PAX6'],
#  ['LMX1B', 'NKX2-2'],
#  ['HDAC1', 'INS'],
#  ['HDAC1', 'PAX6'],
#  ['HDAC1', 'NKX2-2'],
#  ['HDAC1', 'TLE3'],
#  ['NKX2-2', 'PAX6'],
#  ['NKX2-2', 'PAX4'],
#  ['NKX2-2', 'INS'],
#  ['NKX2-2', 'TLE3'],
#  ['PAX4', 'INS'],
#  ['INS', 'PAX6'],
#  ['IDE', 'NGB'],
#  ['CYGB', 'MB'],
#  ['CYGB', 'GBE1'],
#  ['CYGB', 'ADGB'],
#  ['CYGB', 'NGB'],
#  ['NGB', 'GBE1'],
#  ['NGB', 'CYB5A'],
#  ['NGB', 'CYB5B'],
#  ['NGB', 'RHOA'],
#  ['NGB', 'FLOT1'],
#  ['NGB', 'ADGB'],
#  ['NGB', 'CYCS'],
#  ['NGB', 'MB'],
#  ['CYCS', 'RHOA'],
#  ['CYCS', 'CYB5A'],
#  ['CYCS', 'MB'],
#  ['CYCS', 'CYB5B'],
#  ['CYB5B', 'MB'],
#  ['CYB5A', 'MB'],
#  ['MB', 'ADGB'],
#  ['FLOT1', 'RHOA'],
#  ['ADGB', 'GBE1'],
#  ['PATE1', 'LY6G5B'],
#  ['PATE1', 'GLB1L3'],
#  ['PATE1', 'LYPD5'],
#  ['PATE1', 'WFDC8'],
#  ['PATE1', 'PINLYP'],
#  ['PATE1', 'TEX101'],
#  ['PATE1', 'LY6L'],
#  ['PATE1', 'PATE4'],
#  ['PATE1', 'PATE2'],
#  ['PATE1', 'PATE3'],
#  ['PATE2', 'TEX101'],
#  ['PATE2', 'LY6G5B'],
#  ['PATE2', 'GLB1L3'],
#  ['PATE2', 'LYPD5'],
#  ['PATE2', 'PINLYP'],
#  ['PATE2', 'LY6L'],
#  ['PATE2', 'PATE4'],
#  ['PATE2', 'PATE3'],
#  ['LY6G5B', 'TEX101'],
#  ['LY6G5B', 'LYPD5'],
#  ['LY6G5B', 'PATE4'],
#  ['LY6G5B', 'PINLYP'],
#  ['LY6G5B', 'PATE3'],
#  ['LY6G5B', 'LY6L'],
#  ['LYPD5', 'PATE4'],
#  ['LYPD5', 'TEX101'],
#  ['LYPD5', 'PATE3'],
#  ['LYPD5', 'LY6L'],
#  ['LYPD5', 'PINLYP'],
#  ['PATE3', 'TEX101'],
#  ['PATE3', 'GLB1L3'],
#  ['PATE3', 'PINLYP'],
#  ['PATE3', 'LY6L'],
#  ['PATE3', 'PATE4'],
#  ['PATE4', 'TEX101'],
#  ['PATE4', 'PINLYP'],
#  ['PATE4', 'LY6L'],
#  ['LY6L', 'TEX101'],
#  ['LY6L', 'PINLYP'],
#  ['TEX101', 'PINLYP'],
#  ['SLC32A1', 'KCNJ9'],
#  ['SLC32A1', 'ASCL1'],
#  ['SLC32A1', 'SLC6A2'],
#  ['SLC32A1', 'SCRT1'],
#  ['SLC32A1', 'KCNC1'],
#  ['SLC32A1', 'GAD2'],
#  ['SLC32A1', 'SLC17A6'],
#  ['SLC6A2', 'SCRT1'],
#  ['SLC17A6', 'KCNJ9'],
#  ['SLC17A6', 'KCNC1'],
#  ['SLC17A6', 'ASCL1'],
#  ['SLC17A6', 'SCRT1'],
#  ['SLC17A6', 'GAD2'],
#  ['KCNC1', 'GAD2'],
#  ['KCNC1', 'SCRT1'],
#  ['KCNC1', 'KCNJ9'],
#  ['ASCL1', 'GAD2'],
#  ['ASCL1', 'SCRT1'],
#  ['CELF3', 'SCRT1'],
#  ['CDK5R2', 'SCRT1'],
#  ['CNTN2', 'GAD2'],
#  ['CNTN2', 'KCNJ9'],
#  ['CNTN2', 'SCRT1'],
#  ['KCNJ9', 'SCRT1'],
#  ['GAD2', 'SCRT1'],
#  ['C1QL1', 'COL24A1'],
#  ['C1QL1', 'COL9A1'],
#  ['C1QL1', 'NBEAL1'],
#  ['C1QL1', 'COL25A1'],
#  ['C1QL1', 'C1QL4'],
#  ['C1QL1', 'C1QL2'],
#  ['C1QL1', 'C1QTNF1'],
#  ['C1QL1', 'C1QTNF8'],
#  ['C1QL1', 'C1QTNF9'],
#  ['C1QL1', 'ADGRB3'],
#  ['C1QL2', 'C1QL4'],
#  ['C1QL2', 'C1QTNF9'],
#  ['C1QL2', 'C1QTNF1'],
#  ['C1QL2', 'C1QTNF8'],
#  ['C1QL2', 'ADGRB3'],
#  ['C1QTNF8', 'C1QL4'],
#  ['C1QL4', 'COL25A1'],
#  ['C1QL4', 'C1QTNF1'],
#  ['C1QL4', 'ADGRB3'],
#  ['C1QL4', 'C1QTNF9'],
#  ['COL9A1', 'COL24A1'],
#  ['COL9A1', 'COL25A1'],
#  ['COL24A1', 'COL25A1'],
#  ['TCEAL7', 'BEX1'],
#  ['TCEAL7', 'BEX5'],
#  ['TCEAL7', 'BEX3'],
#  ['TCEAL7', 'TCEAL1'],
#  ['TCEAL7', 'TCEAL6'],
#  ['DCAF12L2', 'TCEAL6'],
#  ['TCEAL1', 'TCEAL8'],
#  ['TCEAL1', 'BEX3'],
#  ['TCEAL1', 'TCEAL6'],
#  ['RAB40A', 'BEX5'],
#  ['RAB40A', 'TCEAL6'],
#  ['BEX3', 'BEX2'],
#  ['BEX3', 'TCEAL8'],
#  ['BEX3', 'TCEAL9'],
#  ['BEX3', 'TCEAL6'],
#  ['TCEAL8', 'BEX1'],
#  ['TCEAL8', 'BEX2'],
#  ['TCEAL8', 'TCEAL9'],
#  ['TCEAL8', 'TCEAL6'],
#  ['BEX1', 'BEX5'],
#  ['BEX1', 'TCEAL9'],
#  ['BEX1', 'TCEAL6'],
#  ['TCEAL6', 'BEX2'],
#  ['TCEAL6', 'TCEAL9'],
#  ['TCEAL6', 'BEX5'],
#  ['BEX2', 'TCEAL9'],
#  ['BEX2', 'BEX5'],
#  ['TULP2', 'DMAC2'],
#  ['TULP2', 'IRGQ'],
#  ['TULP2', 'TTC9B'],
#  ['LRFN3', 'SBK1'],
#  ['LRFN3', 'DMAC2'],
#  ['LRFN3', 'ABRACL'],
#  ['LRFN3', 'IRGQ'],
#  ['LRFN3', 'TTC9B'],
#  ['ERICH1', 'TTC9B'],
#  ['HIPK4', 'TTC9B'],
#  ['TTC9B', 'C19orf47'],
#  ['TTC9B', 'SBK1'],
#  ['TTC9B', 'ABRACL'],
#  ['TTC9B', 'IRGQ'],
#  ['TTC9B', 'DMAC2'],
#  ['TTC9B', 'HP1BP3'],
#  ['SBK1', 'DMAC2'],
#  ['SBK1', 'ABRACL'],
#  ['SBK1', 'IRGQ'],
#  ['ABRACL', 'DMAC2'],
#  ['ABRACL', 'IRGQ'],
#  ['IRGQ', 'DMAC2'],
#  ['GNAT1', 'GLYATL1'],
#  ['GNAT1', 'CNGB3'],
#  ['GNAT1', 'PDE6C'],
#  ['GNAT1', 'PDE6H'],
#  ['GNAT1', 'CNGB1'],
#  ['GNAT1', 'CNGA3'],
#  ['GNAT1', 'RPE65'],
#  ['GNAT1', 'OPN4'],
#  ['GNAT1', 'GNAT2'],
#  ['CNGB1', 'PDE6H'],
#  ['CNGB1', 'GNAT2'],
#  ['CNGB1', 'CNGB3'],
#  ['CNGB1', 'PDE6C'],
#  ['CNGB1', 'RPE65'],
#  ['CNGB1', 'CNGA3'],
#  ['CNGB1', 'CNGA2'],
#  ['GNAT2', 'CNGA2'],
#  ['GNAT2', 'RPE65'],
#  ['GNAT2', 'GLYATL1'],
#  ['GNAT2', 'OPN4'],
#  ['GNAT2', 'PDE6H'],
#  ['GNAT2', 'CNGA3'],
#  ['GNAT2', 'PDE6C'],
#  ['GNAT2', 'CNGB3'],
#  ['RPE65', 'PDE6H'],
#  ['RPE65', 'PDE6C'],
#  ['RPE65', 'GLYATL1'],
#  ['RPE65', 'CNGB3'],
#  ['RPE65', 'OPN4'],
#  ['RPE65', 'CNGA3'],
#  ['PDE6H', 'CNGA3'],
#  ['PDE6H', 'CNGB3'],
#  ['PDE6H', 'PDE6C'],
#  ['CNGA3', 'GLYATL1'],
#  ['CNGA3', 'CNGA2'],
#  ['CNGA3', 'OPN4'],
#  ['CNGA3', 'PDE6C'],
#  ['CNGA3', 'CNGB3'],
#  ['GLYATL1', 'CNGB3'],
#  ['GLYATL1', 'PDE6C'],
#  ['GLYATL1', 'OPN4'],
#  ['CNGB3', 'OPN4'],
#  ['CNGB3', 'CNGA2'],
#  ['CNGB3', 'PDE6C'],
#  ['CNGA2', 'OPN4'],
#  ['CNGA2', 'PDE6C'],
#  ['PDE6C', 'OPN4'],
#  ['LEF1', 'OSR2'],
#  ['LEF1', 'SHH'],
#  ['LEF1', 'PITX2'],
#  ['LEF1', 'CTNNB1'],
#  ['LEFTY1', 'CTNNB1'],
#  ['LEFTY1', 'SHH'],
#  ['LEFTY1', 'PITX2'],
#  ['LEFTY1', 'LEFTY2'],
#  ['SHH', 'FOXC1'],
#  ['SHH', 'OSR2'],
#  ['SHH', 'PITX3'],
#  ['SHH', 'LEFTY2'],
#  ['SHH', 'PITX2'],
#  ['SHH', 'CTNNB1'],
#  ['POU1F1', 'PITX2'],
#  ['LEFTY2', 'PITX2'],
#  ['PITX3', 'FOXC1'],
#  ['PITX3', 'PITX2'],
#  ['OSR2', 'FOXC1'],
#  ['OSR2', 'PITX2'],
#  ['CYP1B1', 'PITX2'],
#  ['CYP1B1', 'FOXC1'],
#  ['FOXC1', 'CTNNB1'],
#  ['FOXC1', 'PITX2'],
#  ['PITX2', 'CTNNB1'],
#  ['HOXA2', 'NEUROD4'],
#  ['HOXA2', 'ASCL1'],
#  ['ISL1', 'PROX1'],
#  ['ISL1', 'FOXN4'],
#  ['ISL1', 'ASCL1'],
#  ['ISL1', 'VSX2'],
#  ['ISL1', 'NEUROD4'],
#  ['ISL1', 'PAX6'],
#  ['ISL1', 'POU4F2'],
#  ['ISL1', 'LHX3'],
#  ['NEUROD4', 'POU4F2'],
#  ['NEUROD4', 'PROX1'],
#  ['NEUROD4', 'PAX6'],
#  ['NEUROD4', 'VSX2'],
#  ['NEUROD4', 'HOXB2'],
#  ['NEUROD4', 'LHX3'],
#  ['NEUROD4', 'ASCL1'],
#  ['NEUROD4', 'FOXN4'],
#  ['VSX2', 'LHX3'],
#  ['VSX2', 'PAX6'],
#  ['VSX2', 'ASCL1'],
#  ['VSX2', 'FOXN4'],
#  ['VSX2', 'POU4F2'],
#  ['ASCL1', 'POU4F2'],
#  ['ASCL1', 'LHX3'],
#  ['ASCL1', 'FOXN4'],
#  ['ASCL1', 'HOXB2'],
#  ['ASCL1', 'PAX6'],
#  ['POU4F2', 'LHX3'],
#  ['POU4F2', 'FOXN4'],
#  ['POU4F2', 'PAX6'],
#  ['FOXN4', 'LHX3'],
#  ['FOXN4', 'PAX6'],
#  ['FOXN4', 'PROX1'],
#  ['PROX1', 'PAX6'],
#  ['LHX3', 'PAX6'],
#  ['SCGB2A2', 'MUC1'],
#  ['SCGB2A2', 'ANKRD30A'],
#  ['SCGB2A2', 'ERBB2'],
#  ['SCGB2A2', 'ETV4'],
#  ['SCGB2A2', 'SCGB1D1'],
#  ['SCGB2A2', 'PIP'],
#  ['SCGB2A2', 'SCGB1A1'],
#  ['SCGB2A2', 'SCGB2A1'],
#  ['SCGB2A2', 'MUCL1'],
#  ['SCGB2A2', 'SCGB1D2'],
#  ['SCGB1D2', 'PIP'],
#  ['SCGB1D2', 'MUCL1'],
#  ['SCGB1D2', 'SCGB1D1'],
#  ['SCGB1D2', 'SCGB2A1'],
#  ['SCGB2A1', 'ANKRD30A'],
#  ['SCGB2A1', 'PIP'],
#  ['SCGB2A1', 'SCGB1A1'],
#  ['SCGB2A1', 'SCGB1D1'],
#  ['ERBB2', 'ETV4'],
#  ['ERBB2', 'PIP'],
#  ['ERBB2', 'MUC1'],
#  ['SCGB1A1', 'MUC1'],
#  ['PIP', 'SCGB1D1'],
#  ['PIP', 'MUC1'],
#  ['PIP', 'MUCL1'],
#  ['MUCL1', 'MUC1'],
#  ['DLX2', 'LHX8'],
#  ['DLX2', 'NEUROG2'],
#  ['DLX2', 'BMP4'],
#  ['DLX2', 'TBR1'],
#  ['DLX2', 'MYT1L'],
#  ['DLX2', 'LHX6'],
#  ['DLX2', 'PAX6'],
#  ['DLX2', 'MEIS2'],
#  ['DLX2', 'DLX1'],
#  ['DLX2', 'ASCL1'],
#  ['BMP4', 'LHX8'],
#  ['BMP4', 'ASCL1'],
#  ['BMP4', 'PAX6'],
#  ['BMP4', 'DLX1'],
#  ['ASCL1', 'MEIS2'],
#  ['ASCL1', 'LHX8'],
#  ['ASCL1', 'LHX6'],
#  ['ASCL1', 'TBR1'],
#  ['ASCL1', 'PAX6'],
#  ['ASCL1', 'DLX1'],
#  ['ASCL1', 'MYT1L'],
#  ['ASCL1', 'NEUROG2'],
#  ['LHX8', 'TBR1'],
#  ['LHX8', 'LHX6'],
#  ['LHX8', 'DLX1'],
#  ['NEUROG2', 'LHX6'],
#  ['NEUROG2', 'DLX1'],
#  ['NEUROG2', 'TBR1'],
#  ['NEUROG2', 'MYT1L'],
#  ['NEUROG2', 'PAX6'],
#  ['DLX1', 'MEIS2'],
#  ['DLX1', 'TBR1'],
#  ['DLX1', 'LHX6'],
#  ['DLX1', 'MYT1L'],
#  ['TBR1', 'MYT1L'],
#  ['TBR1', 'LHX6'],
#  ['TBR1', 'PAX6'],
#  ['LHX6', 'MEIS2'],
#  ['LHX6', 'PAX6'],
#  ['MEIS2', 'PAX6'],
#  ['PAX6', 'MYT1L'],
#  ['RTN4R', 'LINGO2'],
#  ['TBPL1', 'LINGO2'],
#  ['TMEM160', 'LINGO2'],
#  ['TMEM160', 'TNNI3K'],
#  ['TMEM160', 'FPGT-TNNI3K'],
#  ['TMEM160', 'SEC16B'],
#  ['TMEM160', 'POC5'],
#  ['TMEM160', 'MTIF3'],
#  ['MOB3B', 'LINGO2'],
#  ['SEC16B', 'POC5'],
#  ['SEC16B', 'LINGO2'],
#  ['SEC16B', 'MTIF3'],
#  ['SEC16B', 'TNNI3K'],
#  ['SEC16B', 'FPGT-TNNI3K'],
#  ['TNNI3K', 'LINGO2'],
#  ['TNNI3K', 'POC5'],
#  ['TNNI3K', 'MTIF3'],
#  ['TNNI3K', 'FPGT-TNNI3K'],
#  ['LINGO2', 'FPGT-TNNI3K'],
#  ['LINGO2', 'POC5'],
#  ['LINGO2', 'MTIF3'],
#  ['LINGO2', 'TFF3'],
#  ['MTIF3', 'POC5'],
#  ['MTIF3', 'FPGT-TNNI3K'],
#  ['POC5', 'FPGT-TNNI3K'],
#  ['TMEM109', 'TMEM151B'],
#  ['TMEM109', 'TMEM116'],
#  ['KCNJ9', 'TMEM151B'],
#  ['KCNJ9', 'SNCB'],
#  ['KCNJ9', 'TMEM235'],
#  ['KCNJ9', 'OPALIN'],
#  ['OPALIN', 'TMEM151B'],
#  ['OPALIN', 'SNCB'],
#  ['OPALIN', 'TMEM235'],
#  ['RIMS3', 'TMEM151B'],
#  ['SNCB', 'TMEM151B'],
#  ['SNCB', 'TMEM235'],
#  ['TMEM151B', 'GDAP1L1'],
#  ['TMEM151B', 'TMEM116'],
#  ['TMEM151B', 'SPATS1'],
#  ['TMEM151B', 'TMEM235'],
#  ['TMEM151B', 'TMEM253'],
#  ['TMEM116', 'TMEM253'],
#  ['EDAR', 'OCA2'],
#  ['EDAR', 'SLC45A2'],
#  ['EDAR', 'SLC24A5'],
#  ['TYR', 'TPCN2'],
#  ['TYR', 'SLC24A4'],
#  ['TYR', 'TYRP1'],
#  ['TYR', 'SLC24A5'],
#  ['TYR', 'DCT'],
#  ['TYR', 'MC1R'],
#  ['TYR', 'SLC45A2'],
#  ['TYR', 'MLANA'],
#  ['TYR', 'OCA2'],
#  ['TPCN2', 'DCT'],
#  ['TPCN2', 'TYRP1'],
#  ['TPCN2', 'MC1R'],
#  ['TPCN2', 'OCA2'],
#  ['TPCN2', 'SLC45A2'],
#  ['TPCN2', 'SLC24A5'],
#  ['TPCN2', 'SLC24A4'],
#  ['SLC45A2', 'DCT'],
#  ['SLC45A2', 'MLANA'],
#  ['SLC45A2', 'SLC24A4'],
#  ['SLC45A2', 'MC1R'],
#  ['SLC45A2', 'TYRP1'],
#  ['SLC45A2', 'OCA2'],
#  ['SLC45A2', 'SLC24A5'],
#  ['SLC24A5', 'MLANA'],
#  ['SLC24A5', 'DCT'],
#  ['SLC24A5', 'MC1R'],
#  ['SLC24A5', 'TYRP1'],
#  ['SLC24A5', 'OCA2'],
#  ['OCA2', 'MLANA'],
#  ['OCA2', 'DCT'],
#  ['OCA2', 'SLC24A4'],
#  ['OCA2', 'MC1R'],
#  ['OCA2', 'TYRP1'],
#  ['MLANA', 'MC1R'],
#  ['MLANA', 'TYRP1'],
#  ['MLANA', 'DCT'],
#  ['TYRP1', 'SLC24A4'],
#  ['TYRP1', 'DCT'],
#  ['TYRP1', 'MC1R'],
#  ['DCT', 'MC1R'],
#  ['SLC24A4', 'MC1R'],
#  ['SLC32A1', 'SLC6A17'],
#  ['SLC1A4', 'SLC6A17'],
#  ['SLC1A4', 'SLC7A5'],
#  ['SLC7A5', 'SLC6A17'],
#  ['SLC6A17', 'RTN4RL1'],
#  ['SLC6A17', 'SLC29A3'],
#  ['SLC6A17', 'FAM135B'],
#  ['SLC6A17', 'UBL4A'],
#  ['SLC6A17', 'TEX15'],
#  ['SLC6A17', 'ALX3'],
#  ['SLC6A17', 'UBL4B'],
#  ['UBL4B', 'UBL4A'],
#  ['UBL4B', 'ALX3'],
#  ['UBL4B', 'TEX15'],
#  ['UBL4A', 'ALX3'],
#  ['UBL4A', 'TEX15'],
#  ['TEX15', 'ALX3'],
#  ['RBM22', 'HNRNPCL1'],
#  ['RBM22', 'CCDC12'],
#  ['RBM22', 'HNRNPC'],
#  ['RBM22', 'RALYL'],
#  ['RBM22', 'PPIE'],
#  ['RBM22', 'XAB2'],
#  ['RALY', 'TIGD3'],
#  ['RALY', 'HNRNPCL2'],
#  ['RALY', 'XAB2'],
#  ['RALY', 'HNRNPCL1'],
#  ['RALY', 'RALYL'],
#  ['RALY', 'HNRNPC'],
#  ['CCDC12', 'RALYL'],
#  ['CCDC12', 'XAB2'],
#  ['CCDC12', 'PPIE'],
#  ['TIGD3', 'OR52N5'],
#  ['TIGD3', 'RALYL'],
#  ['XAB2', 'HNRNPCL1'],
#  ['XAB2', 'HNRNPC'],
#  ['XAB2', 'RALYL'],
#  ['XAB2', 'PPIE'],
#  ['PPIE', 'RALYL'],
#  ['HNRNPCL1', 'HNRNPCL2'],
#  ['HNRNPCL1', 'HNRNPC'],
#  ['HNRNPCL1', 'RALYL'],
#  ['RALYL', 'HNRNPC'],
#  ['RALYL', 'OR52N5'],
#  ['RALYL', 'HNRNPCL2'],
#  ['HNRNPC', 'HNRNPCL2'],
#  ['HNRNPCL2', 'OR52N5'],
#  ['SCO1', 'CRIP3'],
#  ['SCO1', 'COA6'],
#  ['HOXD8', 'CRIP3'],
#  ['HOXD8', 'HOXD3'],
#  ['COA6', 'CRIP3'],
#  ['TGFB2', 'CRIP3'],
#  ['TGFB2', 'HOXD3'],
#  ['HTRA1', 'CRIP3'],
#  ['CRIP3', 'HOXD3'],
#  ['CRIP3', 'MYD88'],
#  ['CRIP3', 'TIRAP'],
#  ['TIRAP', 'MYD88'],
#  ['IGSF21', 'KCNH7'],
#  ['KCNH2', 'KCNH7'],
#  ['KCNH2', 'KCNAB3'],
#  ['KCNH2', 'KCNAB2'],
#  ['KCNH2', 'KCNAB1'],
#  ['PRL', 'KCNH7'],
#  ['KCNAB3', 'KCNAB1'],
#  ['KCNAB3', 'KCNG2'],
#  ['KCNAB3', 'KCNH7'],
#  ['KCNAB3', 'KCNAB2'],
#  ['KCNG2', 'KCNH7'],
#  ['KCNG2', 'KCNAB2'],
#  ['KCNG2', 'KCNAB1'],
#  ['KCNH7', 'SLC4A10'],
#  ['KCNH7', 'KCNAB1'],
#  ['KCNH7', 'KCNAB2'],
#  ['KCNH7', 'IFIH1'],
#  ['KCNH7', 'GCA'],
#  ['KCNAB2', 'KCNAB1'],
#  ['GCA', 'IFIH1'],
#  ['VASP', 'DCC'],
#  ['VASP', 'TRIM9'],
#  ['SNAP25', 'TRIM9'],
#  ['BBOX1', 'TRIM32'],
#  ['BBOX1', 'TRIM9'],
#  ['BBOX1', 'TRIM17'],
#  ['BBOX1', 'TRAT1'],
#  ['FBXW11', 'TRIM9'],
#  ['FBXW11', 'BTRC'],
#  ['TRAT1', 'TRIM32'],
#  ['TRAT1', 'TRIM9'],
#  ['TRAT1', 'TRIM17'],
#  ['TRIM9', 'TRIM32'],
#  ['TRIM9', 'UBE2G2'],
#  ['TRIM9', 'TRIM17'],
#  ['TRIM9', 'DCC'],
#  ['TRIM9', 'BTRC'],
#  ['TRIM17', 'TRIM32'],
#  ['Pdyn', 'Aplnr'],
#  ['Pdyn', 'Npy'],
#  ['Pdyn', 'Pnoc'],
#  ['Pdyn', 'Penk'],
#  ['Pdyn', 'Oprl1'],
#  ['Pdyn', 'Oprd1'],
#  ['Pdyn', 'Oprm1'],
#  ['Pdyn', 'Pomc'],
#  ['Pdyn', 'Oprk1'],
#  ['Npy', 'Aplnr'],
#  ['Npy', 'Oprd1'],
#  ['Npy', 'Oprk1'],
#  ['Npy', 'Oprl1'],
#  ['Npy', 'Oprm1'],
#  ['Npy', 'Penk'],
#  ['Npy', 'Pnoc'],
#  ['Npy', 'Pomc'],
#  ['Mecp2', 'Oprm1'],
#  ['Mecp2', 'Oprk1'],
#  ['Oprd1', 'Aplnr'],
#  ['Oprd1', 'Oprl1'],
#  ['Oprd1', 'Oprk1'],
#  ['Oprd1', 'Oprm1'],
#  ['Oprd1', 'Pnoc'],
#  ['Oprd1', 'Pomc'],
#  ['Oprd1', 'Penk'],
#  ['Aplnr', 'Oprl1'],
#  ['Aplnr', 'Oprm1'],
#  ['Aplnr', 'Penk'],
#  ['Aplnr', 'Pnoc'],
#  ['Aplnr', 'Pomc'],
#  ['Aplnr', 'Oprk1'],
#  ['Pnoc', 'Penk'],
#  ['Pnoc', 'Oprk1'],
#  ['Pnoc', 'Pomc'],
#  ['Pnoc', 'Oprm1'],
#  ['Pnoc', 'Oprl1'],
#  ['Penk', 'Oprk1'],
#  ['Penk', 'Pomc'],
#  ['Penk', 'Oprl1'],
#  ['Penk', 'Oprm1'],
#  ['Oprl1', 'Oprk1'],
#  ['Oprl1', 'Oprm1'],
#  ['Oprl1', 'Pomc'],
#  ['Oprm1', 'Oprk1'],
#  ['Oprm1', 'Pomc'],
#  ['Oprk1', 'Pomc'],
#  ['CDH17', 'CDH26'],
#  ['CDH17', 'CDH10'],
#  ['CDH17', 'CDH13'],
#  ['CDH17', 'CDH9'],
#  ['CDH17', 'CDH20'],
#  ['CDH17', 'CDH22'],
#  ['CDH17', 'CTNNA2'],
#  ['CDH17', 'CTNNA1'],
#  ['CDH17', 'CTNND1'],
#  ['CDH17', 'CTNNB1'],
#  ['CDH9', 'CDH26'],
#  ['CDH9', 'CDH22'],
#  ['CDH9', 'CTNNA2'],
#  ['CDH9', 'CTNND1'],
#  ['CDH9', 'CDH20'],
#  ['CDH9', 'CDH10'],
#  ['CDH9', 'CDH13'],
#  ['CDH9', 'CTNNA1'],
#  ['CDH9', 'CTNNB1'],
#  ['CDH20', 'CTNNA1'],
#  ['CDH20', 'CDH26'],
#  ['CDH20', 'CDH13'],
#  ['CDH20', 'CDH22'],
#  ['CDH20', 'CTNND1'],
#  ['CDH20', 'CTNNA2'],
#  ['CDH20', 'CTNNB1'],
#  ['CDH20', 'CDH10'],
#  ['CDH10', 'CDH26'],
#  ['CDH10', 'CDH22'],
#  ['CDH10', 'CDH13'],
#  ['CDH10', 'CTNNA2'],
#  ['CDH10', 'CTNND1'],
#  ['CDH10', 'CTNNA1'],
#  ['CDH10', 'CTNNB1'],
#  ['CDH13', 'CDH26'],
#  ['CDH13', 'CDH22'],
#  ['CDH13', 'CTNND1'],
#  ['CDH13', 'CTNNA2'],
#  ['CDH13', 'CTNNA1'],
#  ['CDH13', 'CTNNB1'],
#  ['CTNNA1', 'CDH26'],
#  ['CTNNA1', 'CDH22'],
#  ['CTNNA1', 'CTNNA2'],
#  ['CTNNA1', 'CTNND1'],
#  ['CTNNA1', 'CTNNB1'],
#  ['CDH26', 'CTNNB1'],
#  ['CDH26', 'CDH22'],
#  ['CDH26', 'CTNNA2'],
#  ['CDH26', 'CTNND1'],
#  ['CTNND1', 'CDH22'],
#  ['CTNND1', 'CTNNA2'],
#  ['CTNND1', 'CTNNB1'],
#  ['CTNNA2', 'CDH22'],
#  ['CTNNA2', 'CTNNB1'],
#  ['CDH22', 'CTNNB1'],
#  ['ATP12A', 'ATP1A4'],
#  ['ATP12A', 'ATP1A3'],
#  ['ATP12A', 'ATP1A2'],
#  ['ATP12A', 'FXYD2'],
#  ['ATP12A', 'ATP4A'],
#  ['ATP12A', 'LHPP'],
#  ['ATP12A', 'PPA2'],
#  ['ATP12A', 'PPA1'],
#  ['ATP12A', 'ATP4B'],
#  ['CBLIF', 'ATP4A'],
#  ['CBLIF', 'ATP4B'],
#  ['ATP4A', 'FXYD2'],
#  ['ATP4A', 'LHPP'],
#  ['ATP4A', 'PPA2'],
#  ['ATP4A', 'PPA1'],
#  ['ATP4A', 'ATP4B'],
#  ['FXYD2', 'ATP4B'],
#  ['FXYD2', 'ATP1A2'],
#  ['FXYD2', 'ATP1A4'],
#  ['FXYD2', 'ATP1A3'],
#  ['ATP4B', 'ATP1A3'],
#  ['ATP4B', 'ATP1A4'],
#  ['ATP4B', 'ATP1A2'],
#  ['ATP4B', 'PPA2'],
#  ['ATP4B', 'LHPP'],
#  ['ATP4B', 'PPA1'],
#  ['PPA2', 'PPA1'],
#  ['PPA2', 'LHPP'],
#  ['ATP1A2', 'ATP1A4'],
#  ['ATP1A2', 'ATP1A3'],
#  ['ATP1A4', 'ATP1A3'],
#  ['LHPP', 'PPA1'],
#  ['ZNF862', 'FOXN4'],
#  ['NEUROD4', 'VSX1'],
#  ['NEUROD4', 'BARHL2'],
#  ['NEUROD4', 'POU4F2'],
#  ['NEUROD4', 'PROX1'],
#  ['NEUROD4', 'VSX2'],
#  ['NEUROD4', 'FOXN4'],
#  ['VSX2', 'NEUROD1'],
#  ['VSX2', 'PTF1A'],
#  ['VSX2', 'FOXN4'],
#  ['VSX2', 'POU4F2'],
#  ['VSX2', 'ATOH7'],
#  ['POU4F2', 'PTF1A'],
#  ['POU4F2', 'NEUROD1'],
#  ['POU4F2', 'BARHL2'],
#  ['POU4F2', 'FOXN4'],
#  ['POU4F2', 'VSX1'],
#  ['POU4F2', 'ATOH7'],
#  ['NEUROD1', 'BARHL2'],
#  ['NEUROD1', 'PROX1'],
#  ['NEUROD1', 'FOXN4'],
#  ['FOXN4', 'BARHL2'],
#  ['FOXN4', 'VSX1'],
#  ['FOXN4', 'ATOH7'],
#  ['FOXN4', 'PTF1A'],
#  ['FOXN4', 'PROX1'],
#  ['PROX1', 'PTF1A'],
#  ['BARHL2', 'ATOH7'],
#  ['BARHL2', 'PTF1A'],
#  ['ATOH7', 'VSX1'],
#  ['PTF1A', 'VSX1'],
#  ['CYP26B1', 'RARA'],
#  ['CYP26B1', 'RARB'],
#  ['CYP26B1', 'RARS1'],
#  ['CYP26B1', 'CRABP1'],
#  ['CYP26B1', 'CYP26A1'],
#  ['CYP26B1', 'CYP26C1'],
#  ['CYP26A1', 'RARA'],
#  ['CYP26A1', 'RARB'],
#  ['CYP26A1', 'CRABP1'],
#  ['CYP26A1', 'RARS1'],
#  ['CYP26A1', 'CYP26C1'],
#  ['RARS1', 'CYP26C1'],
#  ['RARS1', 'CRABP1'],
#  ['RARS1', 'RARA'],
#  ['RARS1', 'RARB'],
#  ['RARA', 'CYP26C1'],
#  ['RARA', 'HOXA1'],
#  ['RARA', 'CRABP1'],
#  ['RARA', 'RARB'],
#  ['CRABP1', 'RBP3'],
#  ['CRABP1', 'HOXA1'],
#  ['CRABP1', 'NEUROG1'],
#  ['CRABP1', 'CACNA1G'],
#  ['CRABP1', 'RARB'],
#  ['CRABP1', 'CYP26C1'],
#  ['NEUROG1', 'CACNA1G'],
#  ['RARB', 'CYP26C1'],
#  ['DMRT3', 'DMRTA2'],
#  ['DMRT3', 'EMX2'],
#  ['EMX1', 'DMRTA2'],
#  ['SLC18B1', 'DMRTA2'],
#  ['FOXL1', 'DMRTA2'],
#  ['LMX1A', 'DMRTA2'],
#  ['NFIA', 'DMRTA2'],
#  ['FAF1', 'DMRTA2'],
#  ['DMRTA2', 'FOXL3'],
#  ['DMRTA2', 'HMBOX1'],
#  ['DMRTA2', 'EMX2'],
#  ['CD74', 'C14orf180'],
#  ['AQP7', 'C14orf180'],
#  ['AQP7', 'PLIN1'],
#  ['PLIN1', 'C14orf180'],
#  ['PLIN1', 'TRARG1'],
#  ['OR4F4', 'C14orf180'],
#  ['CD300LG', 'C14orf180'],
#  ['OR4F6', 'C14orf180'],
#  ['TRARG1', 'C14orf180'],
#  ...]

# %%
len(all_pairs)
# Out:
# 2778

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df
# Out:
#             TSPAN6  TNMD  DPM1  SCYL3  C1orf112  FGR  CFH  FUCA2  GCLC  NFYA  \
# SRR1797218      99    51    33     67        39  128  597     20   171   153
# SRR1797219      33     2    52    141       110  419  454     57   198   155
# SRR1797220      14    26    11     45        28  197  473     17    90   147
# SRR1797221      14    13     0     23        52   76   65     14    30    11
# SRR1797222      48     0    12    183        53  314  134     60   299   133
# ...            ...   ...   ...    ...       ...  ...  ...    ...   ...   ...
# SRR1797299      85    58   147    117       127    0  222    196   221   642
# SRR1797300      42    85    18     18        41  241  756      9   195   184
# SRR1797301      49     4   121    167       224   47  466     57   444   266
# SRR1797302     109     0    66     27       100  139  583     70   139   212
# SRR1797303       2    23    11     57         1   59  223      0   291   166
#
#             ...  ENSG00000281913  ENSG00000281914  ENSG00000281915  \
# SRR1797218  ...                0                0                0
# SRR1797219  ...                0                0                0
# SRR1797220  ...                0                0                0
# SRR1797221  ...                0                0                0
# SRR1797222  ...                0                0                0
# ...         ...              ...              ...              ...
# SRR1797299  ...                0                0                0
# SRR1797300  ...                0                0                0
# SRR1797301  ...                0                0                0
# SRR1797302  ...                0                0                0
# SRR1797303  ...                0                0                0
#
#             ENSG00000281916  ENSG00000281917  ENSG00000281918  \
# SRR1797218                0                0                0
# SRR1797219                0                0                0
# SRR1797220                0                0                6
# SRR1797221                0                0                0
# SRR1797222                0                0                6
# ...                     ...              ...              ...
# SRR1797299                0                0               12
# SRR1797300                0                0                0
# SRR1797301                0                0               32
# SRR1797302                0                0                0
# SRR1797303                0                0                0
#
#             ENSG00000281919  ENSG00000281920  ENSG00000281921  ENSG00000281922
# SRR1797218                0                0                0                0
# SRR1797219                0                0                0                0
# SRR1797220                0                0                0                0
# SRR1797221                0                1                0                0
# SRR1797222                0                5                0                0
# ...                     ...              ...              ...              ...
# SRR1797299                0                3                0                0
# SRR1797300                0                0                0                0
# SRR1797301                0                0                0                0
# SRR1797302                0                0                0                0
# SRR1797303                0                0                0                0
#
# [86 rows x 65217 columns]

# %%
y = ['healthy' if int(i[-3:]) < 225 else 'cancer' for i in list(df.index.astype(str))]
y[-5:]
# Out:
# ['cancer', 'cancer', 'cancer', 'cancer', 'cancer']

# %%
X = df.values
X_scaled = StandardScaler().fit_transform(X)
X_scaled
# Out:
# array([[ 0.68984067,  2.92912503, -0.42068496, ..., -0.55717466,
#         -0.28420367,  0.        ],
#        [-0.52315054, -0.38808348, -0.05131407, ..., -0.55717466,
#         -0.28420367,  0.        ],
#        [-0.87234498,  1.23667171, -0.84837757, ..., -0.55717466,
#         -0.28420367,  0.        ],
#        ...,
#        [-0.22909207, -0.25268722,  1.29008547, ..., -0.55717466,
#         -0.28420367,  0.        ],
#        [ 0.87362721, -0.52347975,  0.22085395, ..., -0.55717466,
#         -0.28420367,  0.        ],
#        [-1.09288884,  1.03357731, -0.84837757, ..., -0.55717466,
#         -0.28420367,  0.        ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2)

# %%
rf_classifier = RandomForestClassifier(n_estimators=100)
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf_classifier.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#       cancer       1.00      1.00      1.00        17
#      healthy       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18

# %%
importances = rf_classifier.feature_importances_
importances
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
