# %%
import os
import pandas as pd

# %%
dir = os.path.join('..', 'data', 'E-GEOD-60052-raw-counts.tsv')
df = pd.read_csv(dir, sep='\t')
df
# Out:
#                Gene ID Gene Name  SRR1797218  SRR1797219  SRR1797220  \
# 0      ENSG00000000003    TSPAN6          99          33          14
# 1      ENSG00000000005      TNMD          51           2          26
# 2      ENSG00000000419      DPM1          33          52          11
# 3      ENSG00000000457     SCYL3          67         141          45
# 4      ENSG00000000460  C1orf112          39         110          28
# ...                ...       ...         ...         ...         ...
# 65212  ENSG00000281918       NaN           0           0           6
# 65213  ENSG00000281919       NaN           0           0           0
# 65214  ENSG00000281920       NaN           0           0           0
# 65215  ENSG00000281921       NaN           0           0           0
# 65216  ENSG00000281922       NaN           0           0           0
#
#        SRR1797221  SRR1797222  SRR1797223  SRR1797224  SRR1797225  ...  \
# ...

# %%
if 'Gene Name' in df.columns:
    gene_names = df['Gene Name']
    df.drop(columns=['Gene Name'], inplace=True)
df
# Out:
#                Gene ID  SRR1797218  SRR1797219  SRR1797220  SRR1797221  \
# 0      ENSG00000000003          99          33          14          14
# 1      ENSG00000000005          51           2          26          13
# 2      ENSG00000000419          33          52          11           0
# 3      ENSG00000000457          67         141          45          23
# 4      ENSG00000000460          39         110          28          52
# ...                ...         ...         ...         ...         ...
# 65212  ENSG00000281918           0           0           6           0
# 65213  ENSG00000281919           0           0           0           0
# 65214  ENSG00000281920           0           0           0           1
# 65215  ENSG00000281921           0           0           0           0
# 65216  ENSG00000281922           0           0           0           0
#
#        SRR1797222  SRR1797223  SRR1797224  SRR1797225  SRR1797226  ...  \
# ...

# %%
df = df.T
df
# Out:
#                       0                1                2      \
# Gene ID     ENSG00000000003  ENSG00000000005  ENSG00000000419
# SRR1797218               99               51               33
# SRR1797219               33                2               52
# SRR1797220               14               26               11
# SRR1797221               14               13                0
# ...                     ...              ...              ...
# SRR1797299               85               58              147
# SRR1797300               42               85               18
# SRR1797301               49                4              121
# SRR1797302              109                0               66
# SRR1797303                2               23               11
#
#                       3                4                5      \
# Gene ID     ENSG00000000457  ENSG00000000460  ENSG00000000938
# SRR1797218               67               39              128
# ...

# %%
df.columns = df.iloc[0]
df
# Out:
# Gene ID     ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# Gene ID     ENSG00000000003  ENSG00000000005  ENSG00000000419
# SRR1797218               99               51               33
# SRR1797219               33                2               52
# SRR1797220               14               26               11
# SRR1797221               14               13                0
# ...                     ...              ...              ...
# SRR1797299               85               58              147
# SRR1797300               42               85               18
# SRR1797301               49                4              121
# SRR1797302              109                0               66
# SRR1797303                2               23               11
#
# Gene ID     ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# Gene ID     ENSG00000000457  ENSG00000000460  ENSG00000000938
# SRR1797218               67               39              128
# ...

# %%
df = df[1:]
df
# Out:
# Gene ID    ENSG00000000003 ENSG00000000005 ENSG00000000419 ENSG00000000457  \
# SRR1797218              99              51              33              67
# SRR1797219              33               2              52             141
# SRR1797220              14              26              11              45
# SRR1797221              14              13               0              23
# SRR1797222              48               0              12             183
# ...                    ...             ...             ...             ...
# SRR1797299              85              58             147             117
# SRR1797300              42              85              18              18
# SRR1797301              49               4             121             167
# SRR1797302             109               0              66              27
# SRR1797303               2              23              11              57
#
# ...

# %%
df.columns.name = None
df
# Out:
#            ENSG00000000003 ENSG00000000005 ENSG00000000419 ENSG00000000457  \
# SRR1797218              99              51              33              67
# SRR1797219              33               2              52             141
# SRR1797220              14              26              11              45
# SRR1797221              14              13               0              23
# SRR1797222              48               0              12             183
# ...                    ...             ...             ...             ...
# SRR1797299              85              58             147             117
# SRR1797300              42              85              18              18
# SRR1797301              49               4             121             167
# SRR1797302             109               0              66              27
# SRR1797303               2              23              11              57
#
# ...

# %%
X = df.values
X
# Out:
# array([[99, 51, 33, ..., 0, 0, 0],
#        [33, 2, 52, ..., 0, 0, 0],
#        [14, 26, 11, ..., 0, 0, 0],
#        ...,
#        [49, 4, 121, ..., 0, 0, 0],
#        [109, 0, 66, ..., 0, 0, 0],
#        [2, 23, 11, ..., 0, 0, 0]], dtype=object)

# %%
y = df.index.values
y
# Out:
# array(['SRR1797218', 'SRR1797219', 'SRR1797220', 'SRR1797221',
#        'SRR1797222', 'SRR1797223', 'SRR1797224', 'SRR1797225',
#        'SRR1797226', 'SRR1797227', 'SRR1797228', 'SRR1797229',
#        'SRR1797230', 'SRR1797231', 'SRR1797232', 'SRR1797233',
#        'SRR1797234', 'SRR1797235', 'SRR1797236', 'SRR1797237',
#        'SRR1797238', 'SRR1797239', 'SRR1797240', 'SRR1797241',
#        'SRR1797242', 'SRR1797243', 'SRR1797244', 'SRR1797245',
#        'SRR1797246', 'SRR1797247', 'SRR1797248', 'SRR1797249',
#        'SRR1797250', 'SRR1797251', 'SRR1797252', 'SRR1797253',
#        'SRR1797254', 'SRR1797255', 'SRR1797256', 'SRR1797257',
#        'SRR1797258', 'SRR1797259', 'SRR1797260', 'SRR1797261',
#        'SRR1797262', 'SRR1797263', 'SRR1797264', 'SRR1797265',
#        'SRR1797266', 'SRR1797267', 'SRR1797268', 'SRR1797269',
#        'SRR1797270', 'SRR1797271', 'SRR1797272', 'SRR1797273',
#        'SRR1797274', 'SRR1797275', 'SRR1797276', 'SRR1797277',
# ...

# %%
meta_dir = os.path.join('..', 'data', 'E-GEOD-60052-experiment-design.tsv')
meta_df = pd.read_csv(meta_dir, sep='\t')
meta_df
# Out:
#            Run  Sample Characteristic[age]  \
# 0   SRR1797218                        66.0
# 1   SRR1797219                        70.0
# 2   SRR1797220                        45.0
# 3   SRR1797221                        52.0
# 4   SRR1797222                        51.0
# ..         ...                         ...
# 81  SRR1797299                        55.0
# 82  SRR1797300                         NaN
# 83  SRR1797301                        58.0
# 84  SRR1797302                         NaN
# 85  SRR1797303                        70.0
#
#     Sample Characteristic Ontology Term[age]  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 81                                       NaN
# 82                                       NaN
# ...

# %%
meta_df = meta_df[['Run', 'Sample Characteristic[disease]']]
meta_df
# Out:
#            Run Sample Characteristic[disease]
# 0   SRR1797218                         normal
# 1   SRR1797219                         normal
# 2   SRR1797220                         normal
# 3   SRR1797221                         normal
# 4   SRR1797222                         normal
# ..         ...                            ...
# 81  SRR1797299      small cell lung carcinoma
# 82  SRR1797300      small cell lung carcinoma
# 83  SRR1797301      small cell lung carcinoma
# 84  SRR1797302      small cell lung carcinoma
# 85  SRR1797303      small cell lung carcinoma
#
# [86 rows x 2 columns]

# %%
meta_df = meta_df.rename(columns={'Sample Characteristic[disease]':'condition'})
meta_df
# Out:
#            Run                  condition
# 0   SRR1797218                     normal
# 1   SRR1797219                     normal
# 2   SRR1797220                     normal
# 3   SRR1797221                     normal
# 4   SRR1797222                     normal
# ..         ...                        ...
# 81  SRR1797299  small cell lung carcinoma
# 82  SRR1797300  small cell lung carcinoma
# 83  SRR1797301  small cell lung carcinoma
# 84  SRR1797302  small cell lung carcinoma
# 85  SRR1797303  small cell lung carcinoma
#
# [86 rows x 2 columns]

# %%
meta_df = meta_df.set_index('Run')
meta_df.index.name = None
meta_df
# Out:
#                             condition
# SRR1797218                     normal
# SRR1797219                     normal
# SRR1797220                     normal
# SRR1797221                     normal
# SRR1797222                     normal
# ...                               ...
# SRR1797299  small cell lung carcinoma
# SRR1797300  small cell lung carcinoma
# SRR1797301  small cell lung carcinoma
# SRR1797302  small cell lung carcinoma
# SRR1797303  small cell lung carcinoma
#
# [86 rows x 1 columns]
